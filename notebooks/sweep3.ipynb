# %%
# summarize_sweep.py
import wandb
import pandas as pd

# %%
# 1) Point to your sweep
ENTITY  = "test_12342"
PROJECT = "ongsanet-training"
SWEEP_ID = "mqnlylu1"  

api   = wandb.Api()
sweep = api.sweep(f"{ENTITY}/{PROJECT}/{SWEEP_ID}")

# %%
sweep.runs
# Out:
# <Runs test_12342/ongsanet-training>

# %%
records = []
for run in sweep.runs:
    # read config & final metric
    cfg = run.config
    summary = run.summary
    records.append({
        "kernel_size":      cfg.get("kernel_size"),
        "dilation_depth":   cfg.get("dilation_depth"),
        "num_repeat": cfg.get("num_repeat"),
        "num_channels": cfg.get("num_channels"),
        "val_loss":        summary.get("val_loss"),
        "steps":           summary.get("global_step"),  # or summary["_step"]
        "duration_sec":    summary.get("epoch_time_s") * summary.get("epoch") if summary.get("epoch_time_s") else None
    })

    print(cfg)

df = pd.DataFrame(records)
# Out:
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 10}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'batch_size': 128, 'num_repeat': 3, 'kernel_size': 7, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'batch_size': 128, 'num_repeat': 1, 'kernel_size': 7, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'batch_size': 128, 'num_repeat': 3, 'kernel_size': 5, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'batch_size': 128, 'num_repeat': 2, 'kernel_size': 5, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 9}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'batch_size': 128, 'num_repeat': 3, 'kernel_size': 9, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'batch_size': 128, 'num_repeat': 4, 'kernel_size': 9, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 9, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 7, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 12, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 6, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'batch_size': 128, 'num_repeat': 2, 'kernel_size': 5, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 3, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 4, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 3, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 2, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}
# {'cpu': False, 'gpus': 2, 'model': 'models/VOXac30_custom2/VOXac30_custom2.ckpt', 'resume': False, 'devices': 1, 'in_file': 'Dataset/AD_DA_converter.wav', 'out_file': 'Dataset/VOXac30_custom.wav', 'normalize': True, 'tpu_cores': None, 'batch_size': 128, 'max_epochs': 800, 'num_repeat': 1, 'kernel_size': 5, 'sample_time': 0.1, 'cfg_template': 'configs/phase2_base.yaml', 'num_channels': 1, 'learning_rate': 0.005, 'dilation_depth': 8}

# %%
df.sort_values(by='val_loss')
# Out:
#     kernel_size  dilation_depth  num_repeat  num_channels  val_loss steps  \
# 48            9               9           4            12  0.166405  None
# 50            9               9           2            12  0.166663  None
# 33            5              10           3            12  0.166978  None
# 64            7               9           4            12  0.167079  None
# 16            7              10           4            12  0.167275  None
# ..          ...             ...         ...           ...       ...   ...
# 93            5               9           3             1  0.870410  None
# 97            9               8           3            12  0.926452  None
# 95            5               9           1             1  1.024080  None
# 47            5              10           1             1  1.072071  None
# 53            9               9           3             6  1.073936  None
#
#     duration_sec
# 48   1430.584486
# 50    755.964567
# 33   1072.105037
# 64   1414.541446
# 16   1523.993655
# ..           ...
# 93     39.914820
# 97     13.422872
# 95     38.685363
# 47     61.513587
# 53      7.636623
#
# [144 rows x 7 columns]

# %%
df.to_excel('result.xlsx', index=False)

# %%
df_filter = (df[df['num_channels'] < 32
         ].sort_values(by='val_loss'))


# Show all rows without truncation
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df_filter)
# Out:
#      kernel_size  dilation_depth  num_repeat  num_channels  val_loss steps  \
# 48             9               9           4            12  0.166405  None
# 50             9               9           2            12  0.166663  None
# 33             5              10           3            12  0.166978  None
# 64             7               9           4            12  0.167079  None
# 16             7              10           4            12  0.167275  None
# 49             9               9           3            12  0.167684  None
# 34             5              10           2            12  0.168002  None
# 98             9               8           2            12  0.168404  None
# 17             7              10           3            12  0.168520  None
# 4              9              10           4             6  0.168552  None
# 69             7               9           3             6  0.168845  None
# 80             5               9           4            12  0.169243  None
# 5              9              10           3             6  0.169996  None
# 54             9               9           2             6  0.170176  None
# 81             5               9           3            12  0.170271  None
# 70             7               9           2             6  0.170286  None
# 113            7               8           3            12  0.170914  None
# 6              9              10           2             6  0.171198  None
# 128            5               8           4            12  0.171405  None
# 19             7              10           1            12  0.172095  None
# 114            7               8           2            12  0.173040  None
# 101            9               8           3             6  0.173068  None
# 102            9               8           2             6  0.173338  None
# 129            5               8           3            12  0.173434  None
# 67             7               9           1            12  0.174010  None
# 38             5              10           2             6  0.174223  None
# 51             9               9           1            12  0.174268  None
# 130            5               8           2            12  0.174341  None
# 82             5               9           2            12  0.176044  None
# 132            5               8           4             6  0.176188  None
# 35             5              10           1            12  0.176467  None
# 99             9               8           1            12  0.177420  None
# 133            5               8           3             6  0.178288  None
# 7              9              10           1             6  0.179340  None
# 23             7              10           1             6  0.180845  None
# 37             5              10           3             6  0.181998  None
# 134            5               8           2             6  0.183075  None
# 106            9               8           2             3  0.183816  None
# 105            9               8           3             3  0.184321  None
# 73             7               9           3             3  0.184473  None
# 103            9               8           1             6  0.185577  None
# 55             9               9           1             6  0.186329  None
# 84             5               9           4             6  0.186902  None
# 122            7               8           2             3  0.187683  None
# 137            5               8           3             3  0.187724  None
# 72             7               9           4             3  0.188774  None
# 119            7               8           1             6  0.189055  None
# 131            5               8           1            12  0.189959  None
# 20             7              10           4             6  0.190137  None
# 115            7               8           1            12  0.190582  None
# 83             5               9           1            12  0.192763  None
# 11             9              10           1             3  0.194267  None
# 22             7              10           2             6  0.194525  None
# 86             5               9           2             6  0.196799  None
# 118            7               8           2             6  0.196874  None
# 87             5               9           1             6  0.197605  None
# 39             5              10           1             6  0.197841  None
# 71             7               9           1             6  0.198151  None
# 135            5               8           1             6  0.200087  None
# 59             9               9           1             3  0.200141  None
# 10             9              10           2             3  0.202025  None
# 104            9               8           4             3  0.204692  None
# 117            7               8           3             6  0.205968  None
# 66             7               9           2            12  0.207220  None
# 27             7              10           1             3  0.210779  None
# 75             7               9           1             3  0.212919  None
# 107            9               8           1             3  0.214019  None
# 139            5               8           1             3  0.214801  None
# 56             9               9           4             3  0.226146  None
# 120            7               8           4             3  0.226945  None
# 8              9              10           4             3  0.233504  None
# 123            7               8           1             3  0.239958  None
# 91             5               9           1             3  0.242580  None
# 26             7              10           2             3  0.243800  None
# 9              9              10           3             3  0.244711  None
# 25             7              10           3             3  0.244855  None
# 43             5              10           1             3  0.245078  None
# 116            7               8           4             6  0.245541  None
# 18             7              10           2            12  0.248192  None
# 3              9              10           1            12  0.257432  None
# 40             5              10           4             3  0.265258  None
# 74             7               9           2             3  0.266657  None
# 52             9               9           4             6  0.267292  None
# 57             9               9           3             3  0.268819  None
# 21             7              10           3             6  0.271331  None
# 136            5               8           4             3  0.271927  None
# 68             7               9           4             6  0.276422  None
# 41             5              10           3             3  0.281072  None
# 62             9               9           2             1  0.289146  None
# 42             5              10           2             3  0.290541  None
# 109            9               8           3             1  0.299313  None
# 63             9               9           1             1  0.301436  None
# 58             9               9           2             3  0.306730  None
# 110            9               8           2             1  0.310751  None
# 124            7               8           4             1  0.312507  None
# 13             9              10           3             1  0.315116  None
# 88             5               9           4             3  0.315960  None
# 1              9              10           3            12  0.322331  None
# 60             9               9           4             1  0.324715  None
# 125            7               8           3             1  0.328378  None
# 141            5               8           3             1  0.328880  None
# 111            9               8           1             1  0.331327  None
# 36             5              10           4             6  0.338402  None
# 31             7              10           1             1  0.351593  None
# 138            5               8           2             3  0.351882  None
# 142            5               8           2             1  0.352147  None
# 24             7              10           4             3  0.354470  None
# 76             7               9           4             1  0.356653  None
# 94             5               9           2             1  0.365235  None
# 29             7              10           3             1  0.368852  None
# 126            7               8           2             1  0.373112  None
# 61             9               9           3             1  0.373804  None
# 90             5               9           2             3  0.375842  None
# 65             7               9           3            12  0.377160  None
# 108            9               8           4             1  0.379892  None
# 96             9               8           4            12  0.381625  None
# 12             9              10           4             1  0.389142  None
# 14             9              10           2             1  0.389885  None
# 121            7               8           3             3  0.414214  None
# 127            7               8           1             1  0.422794  None
# 89             5               9           3             3  0.422977  None
# 112            7               8           4            12  0.441070  None
# 79             7               9           1             1  0.442009  None
# 143            5               8           1             1  0.444346  None
# 92             5               9           4             1  0.453421  None
# 78             7               9           2             1  0.457330  None
# 28             7              10           4             1  0.474485  None
# 46             5              10           2             1  0.499600  None
# 2              9              10           2            12  0.500272  None
# 45             5              10           3             1  0.515341  None
# 32             5              10           4            12  0.525232  None
# 140            5               8           4             1  0.533783  None
# 30             7              10           2             1  0.562166  None
# 15             9              10           1             1  0.604888  None
# 85             5               9           3             6  0.655830  None
# 100            9               8           4             6  0.661989  None
# 44             5              10           4             1  0.670086  None
# 77             7               9           3             1  0.722237  None
# 0              9              10           4            12  0.764134  None
# 93             5               9           3             1  0.870410  None
# 97             9               8           3            12  0.926452  None
# 95             5               9           1             1  1.024080  None
# 47             5              10           1             1  1.072071  None
# 53             9               9           3             6  1.073936  None
#
#      duration_sec
# 48    1430.584486
# 50     755.964567
# 33    1072.105037
# 64    1414.541446
# 16    1523.993655
# 49     929.300089
# 34     737.304488
# 98     663.971358
# 17    1157.640037
# 4      919.850945
# 69     727.903488
# 80    1328.349616
# 5      694.297249
# 54     432.849260
# 81     212.497659
# 70     498.919142
# 113    940.266829
# 6      350.125493
# 128   1138.562008
# 19     270.965361
# 114    620.924876
# 101    558.708356
# 102    385.566900
# 129    892.688818
# 67     271.848328
# 38     307.216309
# 51     268.397284
# 130    589.576400
# 82      94.336897
# 132    770.589360
# 35     101.873749
# 99     271.768183
# 133    592.579957
# 7       93.516447
# 23      93.733141
# 37      95.414345
# 134    436.780345
# 106    115.413812
# 105    140.890291
# 73     153.864480
# 103     80.071450
# 55      43.088276
# 84      93.427121
# 122    111.131689
# 137    488.802066
# 72      92.902979
# 119     91.987414
# 131    238.474817
# 20     100.672269
# 115     42.193898
# 83      42.750715
# 11      49.423012
# 22      42.169388
# 86      50.439723
# 118     43.245165
# 87      41.946409
# 39      39.144954
# 71      43.759093
# 135    219.186543
# 59      62.237830
# 10      43.822704
# 104     50.247420
# 117     41.951702
# 66      42.478519
# 27      42.847925
# 75      41.147524
# 107     41.526280
# 139    186.245707
# 56      43.574919
# 120     41.658641
# 8       41.240593
# 123     40.714869
# 91      68.803281
# 26      43.606512
# 9       41.855067
# 25      49.683163
# 43      45.999917
# 116     41.745874
# 18      42.613891
# 3       42.716660
# 40      41.808983
# 74      44.503017
# 52      42.299833
# 57      43.959551
# 21      42.361701
# 136     90.547442
# 68      41.673254
# 41      42.428551
# 62      39.821604
# 42      41.362859
# 109     40.364588
# 63      57.904689
# 58      13.021520
# 110     39.689001
# 124     43.086630
# 13      39.324479
# 88      32.970995
# 1       51.279117
# 60      41.323626
# 125     39.795810
# 141    314.178357
# 111     40.826154
# 36      42.528479
# 31      40.531054
# 138     13.147092
# 142    224.386715
# 24      41.645934
# 76      41.736822
# 94      47.056893
# 29      40.964472
# 126     39.893540
# 61      34.661874
# 90      27.935530
# 65      42.235507
# 108     42.942335
# 96      43.403088
# 12      48.990539
# 14      43.247566
# 121     33.307795
# 127     53.872885
# 89      38.635607
# 112     65.236214
# 79      19.967256
# 143    191.712574
# 92      40.340264
# 78      60.743605
# 28      41.187168
# 46      75.364988
# 2       42.508229
# 45      38.031988
# 32      53.620732
# 140     47.572021
# 30      42.954915
# 15      20.293383
# 85      12.798359
# 100     13.174134
# 44      40.121646
# 77      26.207731
# 0       41.034627
# 93      39.914820
# 97      13.422872
# 95      38.685363
# 47      61.513587
# 53       7.636623

# %%
df[df[dia]]['val_loss']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Boxplots of val_loss by each hyperparameter
params = ['kernel_size', 'dilation_depth', 'num_repeat', 'num_channels']
for p in params:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x=df[p], y=np.log10(df['val_loss']))
    plt.title(f'{p} vs. log10(val_loss)')
    plt.xlabel(p)
    plt.ylabel('log10(val_loss)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Define the kernel sizes to plot
kernel_sizes = [5, 7, 9]

for k in kernel_sizes:
    # Filter and pivot
    dfk = df[df["kernel_size"] == k]
    pivot = dfk.pivot_table(
        index="num_repeat",
        columns="num_channels",
        values="val_loss",
        aggfunc="mean"
    )
    
    # Plot heatmap with a fixed color scale (0 to 1)
    plt.figure()
    plt.imshow(pivot.values, aspect='auto', origin='lower', vmin=min(df['val_loss']), vmax=0.5)
    plt.xlabel('num_channels')
    plt.ylabel('num_repeat')
    plt.title(f'Mean val_loss for kernel_size = {k}')
    plt.xticks(range(len(pivot.columns)), pivot.columns)
    plt.yticks(range(len(pivot.index)), pivot.index)
    plt.colorbar(label='val_loss')
    plt.tight_layout()
    plt.show()

# %%
# Define the kernel sizes to plot
kernel_sizes = [5, 7, 9]

for k in kernel_sizes:
    # Filter and pivot
    dfk = df[df["kernel_size"] == k]
    pivot = dfk.pivot_table(
        index="num_repeat",
        columns="dilation_depth",
        values="val_loss",
        aggfunc="mean"
    )
    
    # Plot heatmap with a fixed color scale (0 to 1)
    plt.figure()
    plt.imshow(pivot.values, aspect='auto', origin='lower', vmin=min(df['val_loss']), vmax=0.5)
    plt.xlabel('dilation_depth')
    plt.ylabel('num_repeat')
    plt.title(f'Mean val_loss for kernel_size = {k}')
    plt.xticks(range(len(pivot.columns)), pivot.columns)
    plt.yticks(range(len(pivot.index)), pivot.index)
    plt.colorbar(label='val_loss')
    plt.tight_layout()
    plt.show()

# %%
# Define the kernel sizes to plot
kernel_sizes = [5, 7, 9]

for k in kernel_sizes:
    # Filter and pivot
    dfk = df[df["kernel_size"] == k]
    pivot = dfk.pivot_table(
        index="num_channels",
        columns="dilation_depth",
        values="val_loss",
        aggfunc="mean"
    )
    
    # Plot heatmap with a fixed color scale (0 to 1)
    plt.figure()
    plt.imshow(pivot.values, aspect='auto', origin='lower', vmin=min(df['val_loss']), vmax=0.5)
    plt.xlabel('dilation_depth')
    plt.ylabel('num_channels')
    plt.title(f'Mean val_loss for kernel_size = {k}')
    plt.xticks(range(len(pivot.columns)), pivot.columns)
    plt.yticks(range(len(pivot.index)), pivot.index)
    plt.colorbar(label='val_loss')
    plt.tight_layout()
    plt.show()

# %%
params = ['kernel_size', 'dilation_depth', 'num_repeat', 'num_channels']


df_fil = df[(df['kernel_size'] != 1) & (df['val_loss'] < 0.3)]

# Boxplots of val_loss by each hyperparameter
params = ['kernel_size', 'dilation_depth', 'num_repeat', 'num_channels']
for p in params:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x=df_fil[p], y=df_fil['val_loss'])
    plt.title(f'{p} vs. log10(val_loss)')
    plt.xlabel(p)
    plt.ylabel('log10(val_loss)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
params = ['kernel_size', 'dilation_depth', 'num_repeat', 'num_channels']


df_fil = df[(df['kernel_size'] != 1) & (df['val_loss'] < 0.2)]

# Boxplots of val_loss by each hyperparameter
params = ['kernel_size', 'dilation_depth', 'num_repeat', 'num_channels']
for p in params:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x=df_fil[p], y=df_fil['val_loss'])
    plt.title(f'{p} vs. log10(val_loss)')
    plt.xlabel(p)
    plt.ylabel('log10(val_loss)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

params = ['kernel_size', 'dilation_depth', 'num_repeat', 'num_channels']
for p in params:
    plt.figure()
    plt.scatter(df[p], df['val_loss'])
    plt.title(f'{p} vs. val_loss')
    plt.xlabel(p)
    plt.ylabel('val_loss')
    plt.show()

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/drl-68/.local/lib/python3.10/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in /home/drl-68/miniconda3/envs/wavenet/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/drl-68/.local/lib/python3.10/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/drl-68/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/drl-68/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/drl-68/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/drl-68/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/drl-68/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/drl-68/miniconda3/envs/wavenet/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/drl-68/miniconda3/envs/wavenet/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/drl-68/miniconda3/envs/wavenet/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/drl-68/miniconda3/envs/wavenet/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/drl-68/miniconda3/envs/wavenet/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/drl-68/miniconda3/envs/wavenet/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# WARNING: Error parsing dependencies of gym: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     opencv-python (>=3.) ; extra == 'all'
#                   ~~~~^
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
df[['kernel_size','dilation_depth','num_repeat','num_channels',"val_loss"]].to_excel('hyperparam_results.xlsx', index=False)

# %%
import numpy as np

# %%
# Spearman correlations with val_loss
param_cols = ['kernel_size', 'dilation_depth', 'num_repeat', 'num_channels']
spearman_corr = df[param_cols + ['val_loss']].corr(method='spearman')['val_loss'].drop('val_loss')
spearman_df = spearman_corr.to_frame('spearman_corr').sort_values('spearman_corr', ascending=False)
# display_dataframe_to_user("Spearman correlation (monotonic) with val_loss", spearman_df)

# Bar plot of absolute correlations
plt.figure()
plt.bar(spearman_corr.index, np.abs(spearman_corr.values))
plt.ylabel('|Spearman ρ|')
plt.title('Monotonic strength vs val_loss')
plt.tight_layout()
plt.show()
